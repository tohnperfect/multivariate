# %% [markdown]
# <a href="https://colab.research.google.com/github/tohnperfect/multivariate/blob/main/MVA001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Scalar, Vector, Matrix

# %% [markdown]
# ### Scalar

# %%
import numpy as np

# %%
scalar_a = 10  #scalar
print(scalar_a)
# Out:
# 10

# %% [markdown]
# ## Vector

# %% [markdown]
# ![wp_92-4.png](data:image/png;base64,...)

# %%
vector_b = np.zeros([2,1])  #vector
vector_b[0,0] = 2
vector_b[1,0] = 3
print(vector_b)
print(vector_b.shape)
# Out:
# [[2.]
#  [3.]]
# (2, 1)

# %%
vector_c = np.array([[1],[3]])
print(vector_c)
print(vector_c.shape)
# Out:
# [[1]
#  [3]]
# (2, 1)

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(vector_b[0,0],vector_b[1,0],'or')

# %% [markdown]
# ขนาดของ vector คำนวณได้โดย พิธากอรัส

# %%
vector_b_size = ((vector_b[0,0]**2) + (vector_b[1,0]**2))**0.5
print(vector_b_size)
# Out:
# 3.605551275463989

# %% [markdown]
# ## Matrix

# %% [markdown]
# ![wp_92-4.png](data:image/png;base64,...)

# %%
matrix_d = np.array([[2,3],[1,4],[-1,1]])
print(matrix_d)
# Out:
# [[ 2  3]
#  [ 1  4]
#  [-1  1]]

# %%
matrix_d = matrix_d.T
print(matrix_d)
# Out:
# [[ 2  1 -1]
#  [ 3  4  1]]

# %%
matrix_d[0,:]
# Out:
# array([ 2,  1, -1])

# %%
plt.plot(matrix_d[0,:],matrix_d[1,:], 'or') ## plot(ค่าX, ค่าy, หน้าตาของจุด)
plt.plot(0,0, '.b') 
plt.plot([0,0],[-1,5],'^:k')
plt.plot([-1.5,2.5],[0,0],'>:k')

# %% [markdown]
# ## Transpose

# %%
A = np.array([[3,-1,2],[1,5,4]])
print(A)
# Out:
# [[ 3 -1  2]
#  [ 1  5  4]]

# %%
A.T
# Out:
# array([[ 3,  1],
#        [-1,  5],
#        [ 2,  4]])

# %% [markdown]
# ### Matrix Multiply

# %% [markdown]
# $B = A*A'$

# %%
B = np.dot(A,A.T)
print(B)
# Out:
# [[14  6]
#  [ 6 42]]

# %% [markdown]
# ## Determinant
# $Det(B)$

# %%
np.linalg.det(B)
# Out:
# 551.9999999999998
