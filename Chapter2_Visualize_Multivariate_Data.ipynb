# %% [markdown]
# <a href="https://colab.research.google.com/github/tohnperfect/multivariate/blob/main/Chapter2_Visualize_Multivariate_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ใช้ข้อมูลจาก http://my.ilstu.edu/~gjin/gjtpage/HSC445/Data/AirPollution.html

# %%
import pandas as pd

# %%
pollution_data = pd.read_csv('/content/pollution.txt',sep='\t+') #\t+ คือใช้ tab แบ่งข้อมูล \s+ คือใช้ space แบ่งข้อมูล
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
pollution_data
# Out:
#               City  SO2  Temp   Man   Pop  Wind   Rain  RainDays
# 0          Phoenix   10  70.3   213   582   6.0   7.05        36
# 1      Little Rock   13  61.0    91   132   8.2  48.52       100
# 2    San Francisco   12  56.7   453   716   8.7  20.66        67
# 3           Denver   17  51.9   454   515   9.0  12.95        86
# 4         Hartford   56  49.1   412   158   9.0  43.37       127
# 5       Wilmington   36  54.0    80    80   9.0  40.25       114
# 6       Washington   29  57.3   434   757   9.3  38.89       111
# 7     Jacksonville   14  68.4   136   529   8.8  54.47       116
# 8            Miami   10  75.5   207   335   9.0  59.80       128
# 9          Atlanta   24  61.5   368   497   9.1  48.34       115
# 10         Chicago  110  50.6  3344  3369  10.4  34.44       122
# 11    Indianapolis   28  52.3   361   746   9.7  38.74       121
# 12      Des Moines   17  49.0   104   201  11.2  30.85       103
# 13         Wichita    8  56.6   125   277  12.7  30.58        82
# 14      Louisville   30  55.6   291   593   8.3  43.11       123
# 15     New Orleans    9  68.3   204   361   8.4  56.77       113
# 16       Baltimore   47  55.0   625   905   9.6  41.31       111
# 17         Detroit   35  49.9  1064  1513  10.1  30.96       129
# 18   Minn-St. Paul   29  43.5   699   744  10.6  25.94       137
# 19     Kansas City   14  54.5   381   507  10.0  37.00        99
# 20       St. Louis   56  55.9   775   622   9.5  35.89       105
# 21           Omaha   14  51.5   181   347  10.9  30.18        98
# 22     Albuquerque   11  56.8    46   244   8.9   7.77        58
# 23          Albany   46  47.6    44   116   8.8  33.36       135
# 24         Buffalo   11  47.1   391   463  12.4  36.11       166
# 25      Cincinnati   23  54.0   462   453   7.1  39.04       132
# 26       Cleveland   65  49.7  1007   751  10.9  34.99       155
# 27        Columbus   26  51.5   266   540   8.6  37.01       134
# 28    Philadelphia   69  54.6  1692  1950   9.6  39.93       115
# 29      Pittsburgh   61  50.4   347   520   9.4  36.22       147
# 30      Providence   94  50.0   343   179  10.6  42.75       125
# 31         Memphis   10  61.6   337   624   9.2  49.10       105
# 32       Nashville   18  59.4   275   448   7.9  46.00       119
# 33          Dallas    9  66.2   641   844  10.9  35.94        78
# 34         Houston   10  68.9   721  1233  10.8  48.19       103
# 35  Salt Lake City   28  51.0   137   176   8.7  15.17        89
# 36         Norfolk   31  59.3    96   308  10.6  44.68       116
# 37        Richmond   26  57.8   197   299   7.6  42.59       115
# 38         Seattle   29  51.1   379   531   9.4  38.79       164
# 39      Charleston   31  55.2    35    71   6.5  40.75       148
# 40       Milwaukee   16  45.7   569   717  11.8  29.07       123

# %% [markdown]
# # Very basic plot to visualize any data

# %% [markdown]
# ### scatter plot

# %%
pollution_data.plot.scatter('SO2','Wind')

# %%
pollution_data.plot.scatter('SO2','Wind',s=100,c='r')

# %% [markdown]
# เทคนิคที่1 ใช้ขนาดของจุดแสดงปริมาณของ dimension ที่ 3 ได้

# %%
pollution_data.plot.scatter('SO2','Wind',s = 'RainDays')

# %% [markdown]
# เทคนิคที่2 ใช้สีแสดงปริมาณของ dimension ที่ 3 ได้

# %%
pollution_data.plot.scatter('SO2','Wind',c = 'RainDays')

# %% [markdown]
# ### scatter matrix

# %%
pd.plotting.scatter_matrix(pollution_data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f65af523d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af51c5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af4ea7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af492a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af444cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af478f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af4391d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f65af3eb400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af3eb470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af358198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af30c518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af33c898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af2efc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af2a2f98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f65af25f358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af2126d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af1c3a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af1f7dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af1b5198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af167518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af118898>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f65af0cbc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af0fff98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af0bc358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af06e6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af021a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65aefd2dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af452c50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f65af5eb4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b2bde5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b204f3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af50c390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af508208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af57e438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af7474a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f65af5fbbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b1cd4668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af5606d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65aeff1d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af7a0fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af62c278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b1a424e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f65af8bd748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af6b39b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af708c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af6f2e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65af8e9128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65afb66390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65afb4f5f8>]],
#       dtype=object)

# %%
pd.plotting.scatter_matrix(pollution_data);

# %%
pd.plotting.scatter_matrix(pollution_data,alpha=1.0);

# %%
pd.plotting.scatter_matrix(pollution_data,alpha=0.1);

# %%
pollution_data.plot.scatter('Temp','RainDays',s=100,c='r')

# %% [markdown]
# ### Parallel Coordinate

# %%
example_df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')

# %%
example_df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
pd.plotting.parallel_coordinates(example_df, 'Name')

# %% [markdown]
# #Quiz2
#
# พล้อตกราฟ parallel coordinates ของข้อมูล pollution

# %%
pd.plotting.parallel_coordinates(pollution_data, 'City')

# %% [markdown]
# # จัดกลุ่มตามปริมาณในคอลัมน์ - จัดกลุ่มตามภาค-รัฐ
